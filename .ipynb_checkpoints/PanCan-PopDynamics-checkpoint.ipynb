# %%
using Pkg, DifferentialEquations, PenaltyFunctions, Optim, StatsBase, Plots, CSV, DataFrames, DiffEqParamEstim;

# %% [markdown]
# ## Single Population Growth

# %%
# exponential growth of a single population
function singleExpGrowth(du,u,p,t)
    du[1] = p[1].*u[1]
end
# Out:
# singleExpGrowth (generic function with 1 method)

# %%
# logistic growth of a single population with carrying capacity
function singleLogGrowth(du,u,p,t)
    du[1] = p[1].*u[1].*((p[2]-u[1])./p[2])
end
# Out:
# singleLogGrowth (generic function with 1 method)

# %%
# set initial conditions
param = [0.05]
u0 = [6000];
tspan = (0.0, 72.0);

# define ODE problem & solve
prob = ODEProblem(singleExpGrowth,u0,tspan,param);
sol = solve(prob);

# %%
plot(sol)

# %% [markdown]
# ## Setting Up Parameter Estimation

# %%
function calcAICscore(RSS,n,k)
    AIC = 2.0*(k+1)+n+log(RSS/n)+n*(1+log(2*pi))
end
# Out:
# calcAICscore (generic function with 1 method)

# %% [markdown]
# ## Load Data

# %%
source = "/Users/ferrallm/GitHub/PanCan-PopDynamics/data/LM3-700-NAV_DMSOonly.csv"
datatable = CSV.read(source, DataFrame);
data = Matrix(datatable);

# %%
timepts = [0.0, 6.0, 12.0, 18.0, 24.0, 36.0];
meandata = data[1,:];
meanplussd = data[2,:];
meanminussd = data[3,:];

# %%
scatter(timepts,meandata)
scatter!(timepts,meanplussd)
scatter!(timepts, meanminussd)

# %% [markdown]
# ## Build Loss Function

# %%
# function to calculate the loss: loss(solve(diffeq), data)
function my_loss_func(sol)
    tot_loss = 0.0
    if any((s.retcode != :Success for s in sol.u))
      tot_loss = Inf
    else
        # calculation for the loss here
        for i in 1:length(sol.u)
            solI = sol.u[i]
            x = data[i,(2:end)]
            y = [solI(6)[1],solI(12)[1],solI(18)[1],solI(24)[1],solI(30)[1]]
            tot_loss += sum(((x .- y).^2)./((x).^2))
        end
    end
    tot_loss
end
# Out:
# my_loss_func (generic function with 1 method)

# %% [markdown]
# ## Build Ensemble Problem for Solving ODE with Different Initial Conditions

# %% [raw]
# Note: previous set up as a MonteCarloProblem, no longer a problem type; converting to EnsembleProblem
#
# Previous approach:
# # Set up Monte Carlo Problem
# Nmef = size(dataMEF,1);
# initial_conditionsMEF = Array{Any}(undef,Nmef,1);
# for i=1:Nmef
#    initial_conditionsMEF[i] = [Float64(dataMEF[i,1])];
# end
# function prob_funcMEF(prob,i,repeat)
#   ODEProblem(prob.f,initial_conditionsMEF[i],prob.tspan,prob.p);
# end
# monte_probMEF = MonteCarloProblem(PROB,prob_func=prob_funcMEF);
# simMEF = solve(monte_probMEF,Rodas5(),num_monte=Nmef,parallel_type=:threads);
#
# Link to information on ensemble model: https://docs.sciml.ai/DiffEqDocs/stable/features/ensemble/

# %%
# create initial condition array to pull from

N = size(data,1);
initial_conditions = Array{Any}(undef,N,1);
for i=1:N
   initial_conditions[i] = [Float64(data[i,1])];
end

# %%
# create function that makes that defines the ODE problem with the different initial conditions pulled from data

function prob_func(prob,i,repeat)
  ODEProblem(prob.f,initial_conditions[i],prob.tspan,prob.p);
end
# Out:
# prob_func (generic function with 1 method)

# %%
# build & solve the Ensemble problem 
#     number of trajectories are the number of different initial conditions

monte_prob = EnsembleProblem(prob,prob_func=prob_func);
sim = solve(monte_prob, Rodas5(), EnsembleDistributed(), trajectories = size(initial_conditions)[1]);

# %%
# plot 
plot(sim, linealpha=0.4)

# %%
# calculate loss function -- sum of squared errors for all replicates
err = my_loss_func(sim)
# Out:
# 3.998615475375794

# %% [markdown]
# ## Build Regularized Loss Function

# %% [raw]
# Previous approach with MonteCarloProblem:
#
# #cost_functionMEF = build_loss_objective(monte_probMEF, Vern8(), my_loss_func_MEF, num_monte=Nmef, verbose=true)
# function build_regularized_loss_func(λ)
#     function regularized_loss_func(odeparams)
#         #println("executing cost_func: $odeparams")
#         function prob_funcMEF(prob,i,repeat)
#             ODEProblem(prob.f,initial_conditionsMEF[i],prob.tspan,odeparams);
#         end
#         monte_probMEF = MonteCarloProblem(PROB,prob_func=prob_funcMEF);
#         simMEF = solve(monte_probMEF,
#             Rosenbrock23(autodiff=false), # LinearExponential #Rodas5(),#Vern8(),#Rosenbrock23(autodiff=false),#radau(), #CVODE_BDF(),
#             num_monte=Nmef,
#             parallel_type=:threads,
#             force_dtmin=true,
#            # maxiters = 1000000
#             );
#         return my_loss_func_MEF(simMEF) + λ*sum(abs.(odeparams));
#     end
#     return regularized_loss_func;
# end

# %%
# Build regularized loss function

prob = ODEProblem(singleExpGrowth,u0,tspan,param);

function build_regularized_loss_func(λ)

    function regularized_loss_func(odeparams) 
        
        function prob_func(prob,i,repeat)
            ODEProblem(prob.f,initial_conditions[i],prob.tspan,odeparams);
        end
        
        monte_prob = EnsembleProblem(prob,prob_func=prob_func);
        
        sim = solve(monte_prob, 
            Rosenbrock23(autodiff=false),
            EnsembleDistributed(), 
            trajectories = size(initial_conditions)[1]
        );
        
        return my_loss_func(sim) + λ*sum(abs.(odeparams));
    end
    
    return regularized_loss_func;
end
# Out:
# build_regularized_loss_func (generic function with 1 method)

# %% [markdown]
# ## Run Optimization

# %%
result = @time Optim.optimize(build_regularized_loss_func(0),
    [-5.0], [5.0], ## upper and lower bounds 
    param, 
    Fminbox(LBFGS()),
    Optim.Options(f_tol=0.0, g_tol=1e-16, allow_f_increases=true, iterations=100000))
# Out:
# 1033.674705 seconds (3.05 G allocations: 204.310 GiB, 1.84% gc time, 0.03% compilation time)
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     9.307529e-02
#
#  * Found with
#     Algorithm:     Fminbox with L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 9.99e-11 ≰ 0.0e+00
#     |x - x'|/|x'|          = 2.07e-09 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 1.22e-09 ≰ 1.0e-16
#
#  * Work counters
#     Seconds run:   1034  (vs limit Inf)
#     Iterations:    3
#     f(x) calls:    1477105
#     ∇f(x) calls:   1477105

# %%
paramFIT = result.minimizer
# Out:
# 1-element Vector{Float64}:
#  0.04815387702469971

# %%
paramFitErr = result.minimum
# Out:
# 0.09307529407137771

# %%
println("AIC of Exponential Fit: ", calcAICscore(paramFitErr,size(data)[1],1))
# Out:
# AIC of Exponential Fit: 12.040672410841413

# %%
problem = ODEProblem(singleExpGrowth,u0,tspan,paramFIT)
simFit = solve(problem,Vern8());
plot(simFit)

# %%
scatter!(timepts,meandata)
scatter!(timepts,meanplussd)
scatter!(timepts, meanminussd)

# %%
prob = ODEProblem(singleExpGrowth,u0,tspan,[0.01]);

# %%
result2 = @time Optim.optimize(build_regularized_loss_func(1),
    [-5.0], [5.0], ## upper and lower bounds 
    param, 
    Fminbox(LBFGS()),
    Optim.Options(f_tol=0.0, g_tol=1e-16, allow_f_increases=true, iterations=100000))
# Out:
#   0.163319 seconds (510.12 k allocations: 33.547 MiB)
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.411894e-01
#
#  * Found with
#     Algorithm:     Fminbox with L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.99e-11 ≰ 0.0e+00
#     |x - x'|/|x'|          = 4.14e-10 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 2.61e-10 ≰ 1.0e-16
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    3
#     f(x) calls:    202
#     ∇f(x) calls:   202

# %%
paramFIT2 = result2.minimizer
# Out:
# 1-element Vector{Float64}:
#  0.048074300872902605

# %%
paramFitErr2 = result2.minimum
# Out:
# 0.1411894231390014

# %%
problem2 = ODEProblem(singleExpGrowth,u0,tspan,paramFIT2)
simFit2 = solve(problem2,Vern8());
plot(simFit2)
scatter!(timepts,meandata)
scatter!(timepts,meanplussd)
scatter!(timepts, meanminussd)

# %%
println("AIC of Exponential Fit: ", calcAICscore(paramFitErr2,size(data)[1],1))
# Out:
# AIC of Exponential Fit: 12.457366046883685

# %%
prob = ODEProblem(singleLogGrowth, u0, tspan, [0.01,10000.0]);
result3 = @time Optim.optimize(build_regularized_loss_func(0),
    [-5.0, 0.0], [5.0, 100000000.0], ## upper and lower bounds 
    [0.01,10000.0], 
    Fminbox(LBFGS()),
    Optim.Options(f_tol=0.0, g_tol=1e-16, allow_f_increases=true, iterations=100000))
# Out:
#  11.780755 seconds (38.87 M allocations: 2.497 GiB, 2.07% gc time, 0.27% compilation time)
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.428986e-02
#
#  * Found with
#     Algorithm:     Fminbox with L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.25e+01 ≰ 0.0e+00
#     |x - x'|/|x'|          = 3.55e-04 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 5.77e-10 ≰ 1.0e-16
#
#  * Work counters
#     Seconds run:   12  (vs limit Inf)
#     Iterations:    3
#     f(x) calls:    9178
#     ∇f(x) calls:   9178

# %%
paramFIT3 = result3.minimizer
# Out:
# 2-element Vector{Float64}:
#      0.07452726973708898
#  35095.03905500728

# %%
paramFitErr3 = result3.minimum
# Out:
# 0.014289858001748257

# %%
println("AIC of Logistic Fit: ", calcAICscore(paramFitErr3,size(data)[1],2))
# Out:
# AIC of Logistic Fit: 12.166813686573642

# %%
problem3 = ODEProblem(singleLogGrowth,u0,tspan,paramFIT3)
simFit3 = solve(problem3,Vern8());
plot(simFit3)
scatter!(timepts,meandata)
scatter!(timepts,meanplussd)
scatter!(timepts, meanminussd)

# %%
prob = ODEProblem(singleLogGrowth, u0, tspan, [0.1,10000.0]);
result4 = @time Optim.optimize(build_regularized_loss_func(1),
    [-5.0, 0.0], [5.0, 100000000.0], ## upper and lower bounds 
    [0.01,10000.0], 
    Fminbox(LBFGS()),
    Optim.Options(f_tol=0.0, g_tol=1e-16, allow_f_increases=true, iterations=100000))
# Out:
# ┌ Warning: dt(1.4210854715202004e-14) <= dtmin(1.4210854715202004e-14) at t=8.953181231489579e-5, and step error estimate = 0.6561511798022872. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase ~/.julia/packages/SciMLBase/s9wrq/src/integrator_interface.jl:599
# ┌ Warning: dt(1.4210854715202004e-14) <= dtmin(1.4210854715202004e-14) at t=8.953181231489579e-5, and step error estimate = 0.6561511798022872. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase ~/.julia/packages/SciMLBase/s9wrq/src/integrator_interface.jl:599
# ┌ Warning: dt(1.4210854715202004e-14) <= dtmin(1.4210854715202004e-14) at t=8.953181231489579e-5, and step error estimate = 0.6561511798022872. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase ~/.julia/packages/SciMLBase/s9wrq/src/integrator_interface.jl:599
# ...

# %%
paramFIT4 = result4.minimizer
# Out:
# 2-element Vector{Float64}:
#  3.1903492239537618e-6
#  1.2375436301532428

# %%
paramFitErr4 = result4.minimum
# Out:
# 7.921554786889084

# %%
println("AIC of Logistic Fit: ", calcAICscore(paramFitErr4,size(data)[1],2))
# Out:
# AIC of Logistic Fit: 18.48460640859558

# %%
problem4 = ODEProblem(singleLogGrowth,u0,tspan,paramFIT4)
simFit4 = solve(problem4,Rodas5());
plot(simFit4)
scatter!(timepts,meandata)
scatter!(timepts,meanplussd)
scatter!(timepts, meanminussd)
